# %%
import pandas as pd

# %%
df=pd.read_csv("new_df.csv")

# %%
# Filter the DataFrame to include only rows with verified purchase 'Y'
verified_purchases = df[df['verified_purchase'] == 'Y']
purchased_counts = df['product_id'].value_counts()

# Map the purchased counts back to the original DataFrame
df['purchased_counts'] = df['product_id'].map(purchased_counts).fillna(0)

# # Write the updated DataFrame to a new CSV file
# df.to_csv('output_with_purchased_counts.csv', index=False)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  customer_id       review_id  product_id  \
# 0             0           0     53096384   R63J84G1LOX6R  1563890119
# 1             1           1     53096399  R1BALOA11Z06MT  1559947608
# 2             2           2     53096332  R1LLAY5W5PZUS4  0671701800
# 3             3           3     53096335  R3R9VTJ82FXECQ  0425132153
# 4             4           4     51747709  R1P5J3FNBWTFXY  0517122707
#
#    product_parent                               product_title  \
# 0       763187671  The Sandman Vol. 1: Preludes and Nocturnes
# 1       381720534          The 22 Immutable Laws of Marketing
# 2       860650224                                     Contact
# 3       624269601                                  Good Omens
# 4       161411385                     A Confederacy of Dunces
#
#   product_category  star_rating  helpful_votes  downvotes  total_votes  \
# 0            Books          4.0            0.0        1.0          1.0
# ...

# %%
df.to_csv('new_df.csv')
